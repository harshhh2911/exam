# %%
                                # Question  1
# A
import numpy as np
arr=np.arange(50,100,5).reshape((5,2))
print(arr)
arr=np.reshape(arr,(10,1))
print(arr)

print("_______________________________________\n")

# B
arr=np.random.randint(1,100,20)
print(arr)
mine=np.amin(arr)
maxe=np.amax(arr)
std=np.std(arr)
mean=np.average(arr)
median=np.median(arr)
countuni=np.bincount(arr).size
uniquev=np.unique(arr)
frequent=np.array(uniquev)

print(uniquev,"The number of unique values is ")
print()
print(countuni,"The number of unique values ")
print(frequent)

print("_______________________________________\n")

# C

import numpy as np
i=np.identity(5)*5
print(i)

print("_______________________________________\n")


# D
                    # A + B
arr1=np.random.randint(150,200,10)
arr2=np.random.randint(50,100,10)
print(arr1,arr2)

combined=np.stack((arr1,arr2),axis=1)
print(combined)

                    # C
mh=combined[:,0]
h=np.mean(mh)

mw=combined[:1]
w=np.mean(mw)

arr=[h,w]
print(np.array(arr))

                    # D
h=combined[:,0]
sh=np.argmin(h)
x=combined[:1]
tall=np.argmin(x)
print(sh,tall)

                    # E
sort=h.argsort()
print(h[sort])
                    # F

swap=combined[:,[1,0]]
print(swap)
                    # G
h=combined[:,1]
sort=h.argsort()
print(h[(h[sort]<70)])

# %%
                                #  Question 2 
    
# A
import pandas as pd 
import seaborn as sns
df=sns.load_dataset("penguins")
print(df)


# B
s=df.shape
print(s)

#  C
print(df.info)

#  D
firstfive=df.head()
lastfive=df.tail()
print(firstfive,lastfive)

#  E
x=df.iloc[3:5,[1]]
print(x)

#  F
print(df.describe())

#  G

import pandas as pd
import seaborn as sns
df=sns.load_dataset("penguins")

print("Length and Depth")
print(df['bill_length_mm'].corr(df['bill_depth_mm']))

# %%
                                    # Question 3
# A

import pandas as pd
import seaborn as sns 
df=sns.load_dataset("titanic")
#df.info()


# B

dup_row=df.duplicated()
#print(dup_row)
df=df.drop_duplicates()

miss_val=df.isnull().sum()

#print(miss_val)


# C

a=df.loc[df['survived']==0]
print("Who didn't survived -> ",len(a))

b=df.loc[df['survived']==1]
print("Who did survived -> ",len(b))


#  D

a=df.loc[df['age']<18]
print(len(a))

u18=df[df['age']<18]
sur=u18[u18['survived']==1]
print(len(sur))


#   E

import pandas as pd 
import seaborn as sns 

df=sns.load_dataset("titanic")
x=df['age'].groupby(df['class'])
print(x.mean())



# F

df["Family_size"]=df['sibsp']+df['parch']+1
print(df.head())

# G

df['age'].corr(df['fare'])


# H

# %%
                        #   Question 4
#  A
import matplotlib.pyplot as plt
import pandas as pd 
from sklearn.datasets import load_iris
iris=load_iris()
df=pd.DataFrame(iris.data,columns=iris.feature_names)
plt.scatter(df['petal length (cm)'],df['petal width (cm)'])
plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.title("Iris Flower")
plt.show()


import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
iris=load_iris()

df=pd.DataFrame(iris.data,columns=iris.feature_names)
plt.hist(df["petal length (cm)"])
plt.xlabel("Sepal Length")
plt.ylabel("Frequency")
plt.title("Iris Flower")
plt.show()

vals=[100,60,40,20]
labels=["Apple","Banana","Mango","Lichi"]
plt.pie(vals,labels=labels)
plt.show()


import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import pandas as pd


iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

df['species'] = iris.target
df['species'] = df['species'].map({0: 'setosa', 1: 'versicolor', 2: 'virginica'})

# Create pair plot
sns.pairplot(df)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_iris

# Load the Iris dataset
iris = load_iris()
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['species'] = iris.target_names[iris.target]

# Scatter plot
plt.figure(figsize=(8, 6))
colors = ['blue', 'orange', 'green']
for i, species in enumerate(iris_df['species'].unique()):
    species_data = iris_df[iris_df['species'] == species]
    plt.scatter(species_data['petal length (cm)'], species_data['petal width (cm)'],
                color=colors[i], label=species)
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')
plt.title('Relationship between Petal Length and Petal Width')
plt.legend()
plt.show()





import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_iris

# Load the Iris dataset
iris = load_iris()
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['species'] = iris.target_names[iris.target]

# Pie chart
iris_df['species'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.title('Frequency Count of Flower Types')
plt.axis('equal')
plt.show()
